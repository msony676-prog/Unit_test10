# %% [raw]
# Q1.Two dice are thrown. Find the probability of getting a 3 on the first die and a 5 on the second die.

# %% [raw]
# sample space:
# first die:[1,2,3,4,5,6]
# second die:[1,2,3,4,5,6]
# S=[(1,1),(1,2),.....(6,6)
# total outcomes = 36
# first die = 3
# second die = 5
# only one out come(3,5)
# P(3 on firat,5on second)=favorable outcomes/total outcomes =1/36

# %% [raw]
# Q2. Find the probability of not getting a 6 when a die is thrown.

# %% [raw]
# sample space= 1,2,3,4,5,6
# not getting a 6 = 1,2,3,4,5
# p=5/6

# %% [raw]
# Q3. A disease affects 5% of the population.
# test detects the disease correctly 90% of the time.
# It falsely shows positive for 10% of healthy people.

# %% [raw]
# disease affects = P(D)=0.05
# healthy population =P(H)=0.95
# true positive B/D = 0.9
# false positive B/H = 0.1
# P(B)=P(B/D)*P(D)+P(B/H)*P(H)
# P(B)=0.9*0.05+0.1*0.95
# P(B)=0.045+0.095
# P(B)=0.14
# BAYE'S THEORM
# P(D/B)=P(D)*P(B/D)
#        -----------
#           P(B)
# P(D/B)=0.05*0.9/0.14
#       =0.045/0.14
#       =0.321

# %% [raw]
# Q4. A committee of 2 people is chosen from 4 men and 3 women.
# Find the probability that both are women.

# %% [raw]
# sample space=[M1M2,M1M3,M1M4,M1W1,M1W2,M1W3,.......W2W3]
#             =21
# E=W1W2,W1W3,W2,W3
# P(E)=3/21
#     =1/7
